# %%
import pandas as pd

# %%
rut_parquet = "data/meli_train_data.parquet"
rut_csv = "data/meli_test_data.csv"
rut_jl = "data/items_static_metadata.jl"

# %%
archivo_parquet = pd.read_parquet(rut_parquet)
archivo_csv = pd.read_csv(rut_csv)
archivo_jl = pd.read_json(rut_jl, lines = True)

# %%
archivo_jl.head()
# Out:
#         item_domain_id  item_id  \
# 0         MLB-SNEAKERS   492155
# 1  MLB-SURFBOARD_RACKS   300279
# 2        MLM-NECKLACES    69847
# 3            MLM-RINGS   298603
# 4          MLB-WEBCAMS   345949
#
#                                           item_title site_id  sku product_id  \
# 0    Tênis Masculino Olympikus Cyber Barato Promoçao     MLB    0        NaN
# 1  Suporte Rack Prancha Parede C/ Regulagem Horiz...     MLB    1        NaN
# 2  5 Collares Plateados Dama Gargantilla Choker -...     MLM    2        NaN
# 3  Lindo Anillo De Bella Crepusculo Twilight Prom...     MLM    3        NaN
# 4  Webcam Com Microfone Hd 720p Knup Youtube Pc V...     MLB    4        NaN
#
#   product_family_id
# 0       MLB15832732
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
archivo_csv.head()
# Out:
#       sku  target_stock
# 0  464801             3
# 1  645793             4
# 2   99516             8
# 3  538100             8
# 4  557191            10

# %%
archivo_parquet.head()
# Out:
#       sku        date  sold_quantity  current_price currency listing_type  \
# 0  464801  2021-02-01              0         156.78      REA      classic
# 1  464801  2021-02-02              0         156.78      REA      classic
# 2  464801  2021-02-03              0         156.78      REA      classic
# 3  464801  2021-02-04              0         156.78      REA      classic
# 4  464801  2021-02-05              1         156.78      REA      classic
#
#   shipping_logistic_type shipping_payment  minutes_active
# 0            fulfillment    free_shipping          1440.0
# 1            fulfillment    free_shipping          1440.0
# 2            fulfillment    free_shipping          1440.0
# 3            fulfillment    free_shipping          1440.0
# 4            fulfillment    free_shipping          1440.0

# %%
archivo_parquet.shape
# Out:
# (37660279, 9)

# %%
archivo_parquet.dtypes
# Out:
# sku                         int64
# date                          str
# sold_quantity               int64
# current_price             float64
# currency                      str
# listing_type                  str
# shipping_logistic_type        str
# shipping_payment              str
# minutes_active            float64
# dtype: object

# %%
archivo_parquet['date'].min(),archivo_parquet['date'].max()
# Out:
# ('2021-02-01', '2021-03-31')
